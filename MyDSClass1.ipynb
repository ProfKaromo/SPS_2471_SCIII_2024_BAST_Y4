# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfKaromo/SPS_2471_SCIII_2024_BAST_Y4/blob/main/MyDSClass1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Calling the Data
import pandas as pd
school = pd.read_csv("school.csv")
#school.head(10)
school
# Out:
#        ids        bday  enrolldate   expgradate  Rank  \
# 0    43783   3/22/1995         NaN          NaN   NaN
# 1    20278    1/1/1995         NaN          NaN   NaN
# 2    20389  12/31/1994         NaN          NaN   NaN
# 3    22820   12/1/1994         NaN          NaN   NaN
# 4    24559  11/10/1994         NaN          NaN   NaN
# ..     ...         ...         ...          ...   ...
# 430  34021   7/18/1987  1-Aug-2011  08-May-2017   4.0
# 431  40697   4/29/1987  1-Aug-2011  09-May-2016   4.0
# 432  34272         NaN  1-Aug-2011  09-May-2016   4.0
# 433  33628         NaN  1-Aug-2011  08-May-2017   4.0
# 434  39298         NaN  1-Aug-2011  08-May-2017   4.0
#
#                        Major  Gender  Athlete  Height  Weight  Smoking  \
# 0                        NaN     0.0        0   72.35     NaN      0.0
# 1                 Philosophy     0.0        0   70.66  179.20      0.0
# 2                        NaN     0.0        0   70.68  198.52      0.0
# ...

# %%
#Check on the data dimension
school.shape
# Out:
# (435, 23)

# %%
#Selection of columns
#One column selection
school['Math']
#multiple coulumn selection
school[['Math','Gender','Height','Weight']]
# Out:
#       Math  Gender  Height  Weight
# 0    60.02     0.0   72.35     NaN
# 1    70.19     0.0   70.66  179.20
# 2    71.20     0.0   70.68  198.52
# 3    55.89     1.0     NaN  198.34
# 4    65.52     1.0   67.43  128.17
# ..     ...     ...     ...     ...
# 430  65.31     1.0     NaN     NaN
# 431  70.25     0.0   68.50  131.92
# 432  58.16     0.0   68.10  130.07
# 433  66.84     1.0   69.27  157.26
# 434  60.24     1.0   66.68  152.33
#
# [435 rows x 4 columns]

# %%
#getting statistis from different columns
school['Math'].max()#any posible function can be applied here.
#on a number of columns
school[['Math','Gender','Height','Weight']].mean()
# Out:
# Math       65.468009
# Gender      0.521127
# Height     68.031765
# Weight    181.031569
# dtype: float64

# %%
#checking the missing Data
school.isna().sum()
# Out:
# ids               0
# bday              8
# enrolldate       29
# expgradate       29
# Rank             29
# Major           159
# Gender            9
# Athlete           0
# Height           27
# Weight           59
# Smoking          24
# Sprint           61
# MileMinDur       43
# English          26
# Reading          10
# Math             13
# Writing          31
# State            27
# LiveOnCampus     21
# HowCommute      188
# CommuteTime     188
# SleepTime        32
# StudyTime        42
# dtype: int64

# %%
#Replacing the missing data
school['Gender'].fillna(2.0,inplace=True)

# %%
#imputing using calculated values
meanweight = school['Weight'].mean()
school['Weight'].fillna(meanweight,inplace=True)

# %%
#Replacing the values in a vector
school['Gender'].replace({
    0:"Male",
    1:"Female",
    2:"Neutral"},
                         inplace=True)
school['Gender']
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3      Female
# 4      Female
#         ...
# 430    Female
# 431      Male
# 432      Male
# 433    Female
# 434    Female
# Name: Gender, Length: 435, dtype: object

# %%
school.dropna(subset = ['bday','Reading','Smoking'], inplace=True)
school.shape
# Out:
# (394, 23)

# %%
#Droping duplicates
school.drop_duplicates()
school.shape
# Out:
# (394, 23)

# %%
#Sampling the records
school.sample(5)
# Out:
#        ids       bday  enrolldate   expgradate  Rank  \
# 240  43971  3/18/1993  5-Aug-2013  13-May-2019   2.0
# 291  34212  7/15/1993  6-Aug-2012  14-May-2018   3.0
# 164  34176  7/17/1992  4-Aug-2014  13-May-2019   1.0
# 185  22617  12/4/1994  5-Aug-2013  14-May-2018   2.0
# 78   49326  1/14/1995  4-Aug-2014  13-May-2019   1.0
#
#                                           Major  Gender  Athlete  Height  \
# 240                                         NaN  Female        1   64.70
# 291                                epidemiology  Female        1   69.66
# 164                                          CS    Male        1   69.70
# 185  graphic design with a minor in photography    Male        1   74.05
# 78                                          NaN    Male        0   72.85
#
#          Weight  ...  English  Reading   Math  Writing         State  \
# 240  182.590000  ...    83.27    80.54  70.55    86.27      In state
# ...

# %%
#Describing the data
school.describe()
# Out:
#                 ids        Rank     Athlete      Height      Weight  \
# count    394.000000  372.000000  394.000000  370.000000  394.000000
# mean   35309.256345    2.193548    0.418782   68.011108  181.418532
# std     8699.449736    1.098964    0.493987    5.324718   40.467574
# min    20183.000000    1.000000    0.000000   55.000000  101.710000
# 25%    27650.500000    1.000000    0.000000   64.840000  155.900000
# 50%    35786.500000    2.000000    0.000000   67.525000  180.920785
# 75%    42779.500000    3.000000    1.000000   71.440000  198.517500
# max    49947.000000    4.000000    1.000000   84.410000  350.070000
#
#           Smoking      Sprint     English     Reading        Math     Writing  \
# count  394.000000  338.000000  368.000000  394.000000  381.000000  366.000000
# mean     0.431472    6.592322   82.952609   82.105914   65.601391   79.584098
# std      0.766091    1.228668    6.759878    7.754044    8.490330    5.549979
# ...

# %%
#Correlation
school.corr()
# Out:
# <ipython-input-17-499c9c970bc1>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   school.corr()
#                    ids      Rank   Athlete    Height    Weight   Smoking  \
# ids           1.000000 -0.067941 -0.022231  0.032760 -0.000287  0.125300
# Rank         -0.067941  1.000000 -0.004968  0.017343 -0.032806  0.060371
# Athlete      -0.022231 -0.004968  1.000000  0.173411 -0.143966 -0.203010
# Height        0.032760  0.017343  0.173411  1.000000  0.497213 -0.091212
# Weight       -0.000287 -0.032806 -0.143966  0.497213  1.000000  0.019283
# Smoking       0.125300  0.060371 -0.203010 -0.091212  0.019283  1.000000
# Sprint        0.063672  0.044587 -0.785983 -0.072054 -0.084646  0.209042
# English      -0.032270  0.082757 -0.060406 -0.040537  0.028124 -0.003985
# ...

# %%
#Grouping function
school.groupby('Gender').size()
# Out:
# Gender
# 0.0    204
# 1.0    222
# 2.0      9
# dtype: int64

# %%
#statistics based on category
school.groupby('Gender')['Math','English','Reading'].mean()
# Out:
# <ipython-input-19-c492dab32aa7>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   school.groupby('Gender')['Math','English','Reading'].mean()
#               Math    English    Reading
# Gender
# Female   64.357716  82.860154  82.221520
# Male     66.842571  82.951515  81.790331
# Neutral  68.690000  85.228750  85.832222

# %%
#Grouping by more than one category
school.groupby(['Gender','State','Rank'])['Math','English','Reading'].mean()
# Out:
# <ipython-input-20-f723f35c8f57>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   school.groupby(['Gender','State','Rank'])['Math','English','Reading'].mean()
#                                 Math    English    Reading
# Gender  State        Rank
# Female  In state     1.0   64.724167  82.299592  81.213200
#                      2.0   64.008966  82.330000  83.030000
#                      3.0   64.426571  84.072571  83.366944
#                      4.0   61.698889  82.114211  81.350526
#         Out of state 1.0   65.409412  83.470000  80.230000
#                      2.0   65.397500  85.717500  85.554444
#                      3.0   66.751667  82.748333  84.133077
#                      4.0   62.615556  83.043750  80.121111
# Male    In state     1.0   66.028333  81.671915  80.909200
#                      2.0   67.618519  82.335000  82.127500
# ...

# %%
#check for the smalest record based on a column
school.nsmallest(10,'Math')
# Out:
#        ids        bday  enrolldate   expgradate  Rank  \
# 72   44517   3/11/1995  4-Aug-2014  11-May-2020   1.0
# 79   49155   1/13/1995  4-Aug-2014  11-May-2020   1.0
# 415  48958   1/17/1990  1-Aug-2011  09-May-2016   4.0
# 114  43610   3/23/1994  4-Aug-2014  11-May-2020   1.0
# 342  35681   6/28/1991  6-Aug-2012  14-May-2018   3.0
# 229  35687   6/26/1993  5-Aug-2013  13-May-2019   2.0
# 176  20255    1/1/1996  5-Aug-2013  14-May-2018   2.0
# 313  27177   10/9/1992  6-Aug-2012  08-May-2017   3.0
# 309  23514  11/22/1992  6-Aug-2012  08-May-2017   3.0
# 181  34623   7/10/1995  5-Aug-2013  14-May-2018   2.0
#
#                                        Major  Gender  Athlete  Height  \
# 72                     Environmental Science  Female        1   66.07
# 79                                   English  Female        0   62.20
# 415                                Fein Arts  Female        1   66.14
# 114                               Studio art  Female        0   69.70
# ...

# %%
#Aggregate
school['Height'].agg(['mean','std','min','max','median'])
# Out:
# mean      68.011108
# std        5.324718
# min       55.000000
# max       84.410000
# median    67.525000
# Name: Height, dtype: float64

# %%
#Sorting
school.sort_values('Math', ascending = False).head(3)
# Out:
#        ids        bday  enrolldate   expgradate  Rank           Major  Gender  \
# 352  26034  10/24/1990  6-Aug-2012  08-May-2017   3.0  aaaaaaaaaaaaaa  Female
# 419  23340  11/26/1989  1-Aug-2011  08-May-2017   4.0     AstronomyÂ   Female
# 331  47122    2/7/1992  6-Aug-2012  14-May-2018   3.0             NaN  Female
#
#      Athlete  Height  Weight  ...  English  Reading   Math  Writing  \
# 352        1   66.63  153.12  ...    89.29    96.80  93.78    88.77
# 419        1   64.46  134.77  ...    75.05    88.79  85.69    83.22
# 331        0   62.01  177.30  ...    77.71    99.35  85.57    87.08
#
#             State  LiveOnCampus  HowCommute CommuteTime  SleepTime  StudyTime
# 352  Out of state           0.0         3.0        22.0        7.0       10.0
# 419           NaN           0.0         3.0        19.0        4.0        8.0
# 331      In state           0.0         3.0        29.0        9.0        6.0
#
# [3 rows x 23 columns]

# %%
school = school.assign(NewVar_Total= lambda school : school.English+school.Reading).head(10)
school.head(10)
school['NewVar_Total']
# Out:
# 0     169.74
# 1     174.70
# 2     183.61
# 4     159.91
# 6     166.51
# 7        NaN
# 8     152.19
# 9     162.15
# 10    177.34
# 12    176.40
# Name: NewVar_Total, dtype: float64

# %%
# Add a new column, with > 50 - Pass/< 50 - Fail based on Math
import numpy
pd.set_option('display.max_columns', None)#Helps to see all the columns
school['Performance'] = numpy.where(school['Math'] >=65, "Passed", "Failed")
school.head(2)
# Out:
#      ids       bday enrolldate expgradate  Rank       Major Gender  Athlete  \
# 0  43783  3/22/1995        NaN        NaN   NaN         NaN   Male        0
# 1  20278   1/1/1995        NaN        NaN   NaN  Philosophy   Male        0
#
#    Height      Weight  Smoking  Sprint MileMinDur  English  Reading   Math  \
# 0   72.35  181.031569      0.0   7.978        NaN    88.24    81.50  60.02
# 1   70.66  179.200000      0.0   8.004    0:06:21    89.45    85.25  70.19
#
#    Writing     State  LiveOnCampus  HowCommute  CommuteTime  SleepTime  \
# 0    81.44  In state           1.0         NaN          NaN        7.0
# 1    73.27       NaN           1.0         NaN          NaN        5.0
#
#    StudyTime  NewVar_Total Performance
# 0        1.0        169.74      Failed
# 1        2.0        174.70      Passed

# %%
#Creating own functio
def myfxn(x):
  ans = 0.4563*x
  return ans

school['Weight'] = school['Weight'].apply(myfxn)
school.head(5)
# Out:
#      ids        bday enrolldate expgradate  Rank         Major  Gender  \
# 0  43783   3/22/1995        NaN        NaN   NaN           NaN    Male
# 1  20278    1/1/1995        NaN        NaN   NaN    Philosophy    Male
# 2  20389  12/31/1994        NaN        NaN   NaN           NaN    Male
# 4  24559  11/10/1994        NaN        NaN   NaN           NaN  Female
# 6  33312   7/27/1994        NaN        NaN   NaN  Anthropology    Male
#
#    Athlete  Height     Weight  Smoking  Sprint MileMinDur  English  Reading  \
# 0        0   72.35  82.604705      0.0   7.978        NaN    88.24    81.50
# 1        0   70.66  81.768960      0.0   8.004    0:06:21    89.45    85.25
# 2        0   70.68  90.584676      0.0     NaN    0:07:00    96.73    86.88
# 4        1   67.43  58.483971      2.0     NaN    0:06:25    82.61    77.30
# 6        1   68.56  74.814948      0.0   4.750    0:05:47    78.98    87.53
#
#     Math  Writing         State  LiveOnCampus  HowCommute  CommuteTime  \
# ...

# %%
# Seaborn and Matplotlib
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
school.groupby('Gender').size().plot(kind='pie', autopct = '%2.2f%%', explode = (0.1, 0.1, 0.4))
# Out:
# <Axes: >

# %%
#Save the cleaned data
school.to_csv('MyNEwSchoolData.csv')

# %%
# Out:
#        ids        bday  enrolldate   expgradate  Rank  \
# 0    43783   3/22/1995         NaN          NaN   NaN
# 1    20278    1/1/1995         NaN          NaN   NaN
# 2    20389  12/31/1994         NaN          NaN   NaN
# 3    22820   12/1/1994         NaN          NaN   NaN
# 4    24559  11/10/1994         NaN          NaN   NaN
# ..     ...         ...         ...          ...   ...
# 430  34021   7/18/1987  1-Aug-2011  08-May-2017   4.0
# 431  40697   4/29/1987  1-Aug-2011  09-May-2016   4.0
# 432  34272         NaN  1-Aug-2011  09-May-2016   4.0
# 433  33628         NaN  1-Aug-2011  08-May-2017   4.0
# 434  39298         NaN  1-Aug-2011  08-May-2017   4.0
#
#                        Major  Gender  Athlete  Height  Weight  Smoking  \
# 0                        NaN     0.0        0   72.35     NaN      0.0
# 1                 Philosophy     0.0        0   70.66  179.20      0.0
# 2                        NaN     0.0        0   70.68  198.52      0.0
# ...
